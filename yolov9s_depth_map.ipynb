# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.11.6 x86_64-unknown-linux-gnu
# installing to /root/.local/bin
#   uv
#   uvx
# everything's installed!
#
# To add $HOME/.local/bin to your PATH, either restart your shell or run:
#
#     source $HOME/.local/bin/env (sh, bash, zsh)
#     source $HOME/.local/bin/env.fish (fish)
# WARN: The following commands are shadowed by other commands in your PATH: uv uvx

# %%
import os
os.environ["PATH"] += ":/root/.local/bin"

# %%
# %%writefile requirements.txt
# torch==2.2.2
# torchvision==0.17.2
# torchaudio==2.2.2
# numpy==1.26.4
# ultralytics
# pandas
# seaborn
# export
# gitpython
# ipython
# matplotlib>=3.2.2
# Pillow>=7.1.2
# psutil
# PyYAML>=5.3.1
# requests>=2.23.0
# scipy>=1.4.1
# thop>=0.1.1
# tqdm>=4.64.0
# tensorboard>=2.4.1
# pandas>=1.1.4
# seaborn>=0.11.0
# albumentations==1.3.1
# pycocotools
# setuptools<71
# Out:
# Writing requirements.txt

# %%
# !uv venv
# Out:
# Using CPython 3.11.14
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate

# %%
# !uv pip install -r requirements.txt
# Out:
# ⠙ Resolving dependencies...
# Resolved 90 packages in 951ms
# ⠙ Preparing packages... (0/70)
# ⠙ Preparing packages... (0/70)------------------     0 B/150.08 KiB
# ⠙ Preparing packages... (0/70)------------------ 14.88 KiB/150.08 KiB
# ⠙ Preparing packages... (0/70)------------------ 14.88 KiB/150.08 KiB
# certifi              ------------------------------ 14.88 KiB/150.08 KiB
# ⠙ Preparing packages... (0/70)------------------     0 B/1.97 MiB
# certifi              ------------------------------ 14.88 KiB/150.08 KiB
# ⠙ Preparing packages... (0/70)------------------     0 B/1.97 MiB
# certifi              ------------------------------ 14.88 KiB/150.08 KiB
# ⠙ Preparing packages... (0/70)------------------     0 B/1.97 MiB
# certifi              ------------------------------ 14.88 KiB/150.08 KiB
# mpmath               ------------------------------     0 B/523.63 KiB
# ⠙ Preparing packages... (0/70)------------------     0 B/1.97 MiB
# ...

# %%
# chạy các dòng ở dưới trong terminal
# source /root/.venv/bin/activate
# python -m ensurepip --upgrade
# python -m pip install --upgrade pip
# python -m pip install ipykernel

# %%
# !git config --global user.email "tranvanquyet09112005@gmail.com"
# !git config --global user.name "TVQuyet05"
# !git clone https://{token}@github.com/{repo}
# git clone https://github.com/TVQuyet05/yolov9_GRL_Domain_Adaptation.git

# %%
# %cd ./yolov9_GRL_Domain_Adaptation/
# Out:
# /root/yolov9_GRL_Domain_Adaptation

# %%
# !pwd
# Out:
# /root/yolov9_GRL_Domain_Adaptation

# %%
# !pip install -U gdown
## download clear data
# !gdown 1TgRR3ZALsc5bD9RVMGy-4xKHfPvzM72y
## download foggy data
# !gdown 1bZndV5mAhb6DmZEYiDdfFr8JXj89Pdez
# !apt update
# !apt install -y unzip
# !unzip ./mid_cityscapes_8_subset.zip -d ./my_dataset/
# !unzip ./mid_foggy_cityscapes_subset_8.zip -d ./my_dataset/
# !mv '/root/mean_teacher_student_yolo/my_dataset/content/mount/MyDrive/2025fog/foggy_zurich_direct' ./my_dataset/
# Out:
# Archive:  ./mid_foggy_cityscapes_subset_8.zip
#    creating: ./my_dataset/mid_foggy_cityscapes_subset/
#    creating: ./my_dataset/mid_foggy_cityscapes_subset/train/
#    creating: ./my_dataset/mid_foggy_cityscapes_subset/train/labels/
#   inflating: ./my_dataset/mid_foggy_cityscapes_subset/train/labels/cologne_000013_000019_leftImg8bit.txt
#   inflating: ./my_dataset/mid_foggy_cityscapes_subset/train/labels/weimar_000105_000019_leftImg8bit.txt
#   inflating: ./my_dataset/mid_foggy_cityscapes_subset/train/labels/bremen_000154_000019_leftImg8bit.txt
#   inflating: ./my_dataset/mid_foggy_cityscapes_subset/train/labels/hamburg_000000_088054_leftImg8bit.txt
#   inflating: ./my_dataset/mid_foggy_cityscapes_subset/train/labels/darmstadt_000053_000019_leftImg8bit.txt
#   inflating: ./my_dataset/mid_foggy_cityscapes_subset/train/labels/bochum_000000_013209_leftImg8bit.txt
#   inflating: ./my_dataset/mid_foggy_cityscapes_subset/train/labels/tubingen_000104_000019_leftImg8bit.txt
# ...

# %%
# depth maps mid train cityscapes
# !gdown 15CWg_GqQnvV_NIRJOeY3NqIVTnOyAi38
# !unzip ./depth_maps_npy_cityscapes_mid_train.zip -d ./my_dataset/
# Out:
# Archive:  ./depth_maps_npy_cityscapes_mid_train.zip
#    creating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_cityscapes_train/
#   inflating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_cityscapes_train/weimar_000095_000019_leftImg8bitnpy.npy
#   inflating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_cityscapes_train/dusseldorf_000152_000019_leftImg8bitnpy.npy
#   inflating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_cityscapes_train/bochum_000000_006746_leftImg8bitnpy.npy
#   inflating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_cityscapes_train/cologne_000084_000019_leftImg8bitnpy.npy
#   inflating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_cityscapes_train/tubingen_000006_000019_leftImg8bitnpy.npy
#   inflating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_cityscapes_train/bremen_000295_000019_leftImg8bitnpy.npy
# ...

# %%
# depth maps val cityscapes 
# !gdown 1g13EgRf5PJc-GXeFOcWTAIlf69Hce_g2
# !unzip ./depth_maps_npy_cityscapes_val.zip -d ./my_dataset/
# Out:
# Archive:  ./depth_maps_npy_cityscapes_val.zip
#    creating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_val/
#   inflating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_val/frankfurt_000001_012519_leftImg8bitnpy.npy
#   inflating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_val/munster_000131_000019_leftImg8bitnpy.npy
#   inflating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_val/frankfurt_000001_041074_leftImg8bitnpy.npy
#   inflating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_val/munster_000094_000019_leftImg8bitnpy.npy
#   inflating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_val/frankfurt_000001_003056_leftImg8bitnpy.npy
#   inflating: ./my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_val/frankfurt_000000_011074_leftImg8bitnpy.npy
# ...

# %%
# %%writefile data_depth.yaml
# train: /root/yolov9_GRL_Domain_Adaptation/my_dataset/mini_cityscapes_8_subset/train/images
# train_depth: /root/yolov9_GRL_Domain_Adaptation/my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_cityscapes_train
# val: /root/yolov9_GRL_Domain_Adaptation/my_dataset/mini_cityscapes_8_subset/val/images
# val_depth: /root/yolov9_GRL_Domain_Adaptation/my_dataset/root/Depth-Anything-V2/metric_depth/depth_map_numpy_val
#
# nc: 8
# names:
#   0 : person
#   1 : rider
#   2 : car
#   3 : train
#   4 : bicycle
#   5 : motorcycle
#   6 : truck
#   7 : bus
# Out:
# Overwriting data_depth.yaml

# %%
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-s.pt
# Out:
# --2026-04-14 17:29:41--  https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-s.pt
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response...
# 302 Found
# ...

# %%
# !apt update
# !apt install -y libgl1
# Out:
# 0% [Working]
# Hit:1 http://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu noble InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu noble-backports InRelease
# Reading package lists... Done3m
# Building dependency tree... Done
# Reading state information... Done
# 28 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgl1 is already the newest version (1.7.0-1build1).
# libgl1 set to manually installed.
# ...

# %%
# !python3 train_depth.py --cfg models/detect/yolov9-s.yaml --data data_depth.yaml --epochs 100 --batch-size 8 --imgsz 640 --device 0

# %%
# !python3 train_depth.py --workers 32 --device 0 --batch 64 --data ./data_depth.yaml --img 640 --cfg models/detect/yolov9-s.yaml --weights './yolov9-s.pt' --name yolov9-s --hyp hyp.scratch-high.yaml --min-items 0 --epochs 100 --close-mosaic 15
# Out:
# train_depth: weights=./yolov9-s.pt, cfg=models/detect/yolov9-s.yaml, data=./data_depth.yaml, hyp=hyp.scratch-high.yaml, epochs=100, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=32, project=runs/train, name=yolov9-s, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 45a25db Python-3.12.3 torch-2.2.2+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40442MiB)
#
# ...

# %%
# !python val_depth.py --data ./data_depth.yaml --img 640 --batch 64 --conf 0.001 --iou 0.7 --device 0 --weights '/root/yolov9_GRL_Domain_Adaptation/runs/train/yolov9-s4/weights/best.pt' --save-json --half --name yolov9_c_640_val
# Out:
# val_depth: data=./data_depth.yaml, weights=['/root/yolov9_GRL_Domain_Adaptation/runs/train/yolov9-s4/weights/best.pt'], batch_size=64, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=yolov9_c_640_val, exist_ok=False, half=True, dnn=False, min_items=0
# YOLO 🚀 45a25db Python-3.12.3 torch-2.2.2+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40442MiB)
#
# Fusing layers...
# yolov9-s summary: 668 layers, 9608322 parameters, 0 gradients, 38.7 GFLOPs
# val: Scanning /root/yolov9_GRL_Domain_Adaptation/my_dataset/mid_foggy_cityscapes
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       9792      0.615      0.289       0.34      0.221
#                 person        500       3278      0.576      0.362      0.396      0.238
# ...

# %%
# !CUDAVISIaBLE_DEVICES=0 WANDB_MODE=disabled python3 train_dual_mean_teacher.py --workers 16 --device 0 --batch 32 --data ./data1.yaml --img 640 --cfg ./models/detect/yolov9-s.yaml --weights './yolov9-s.pt' --hyp hyp.scratch-high.yaml --min-items 0 --epochs 100 --close-mosaic 15
# Out:
# train_dual_mean_teacher: weights=./yolov9-s.pt, cfg=./models/detect/yolov9-s.yaml, data=./data1.yaml, hyp=hyp.scratch-high.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=16, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, weight_consistency_loss=10000.0, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, fda_beta=0.1
# YOLO 🚀 fd2ba12 Python-3.12.3 torch-2.2.2+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40444MiB)
#
# ...

# %%
# !python val_dual.py --data ./data1.yaml --img 640 --batch 32 --conf 0.001 --iou 0.7 --device 0 --weights '/root/mean_teacher_student_yolo/runs/train/exp/weights/best.pt' --save-json --name yolov9_c_640_val
# Out:
# /root/mean_teacher_student_yolo/utils/general.py:29: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# val_dual: data=./data1.yaml, weights=['/root/mean_teacher_student_yolo/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.2, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=yolov9_c_640_val, exist_ok=False, half=False, dnn=False, min_items=0
# WARNING ⚠️ confidence threshold 0.2 > 0.001 produces invalid results
# YOLO 🚀 00168e2 Python-3.11.14 torch-2.2.2+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
#
# Fusing layers...
# ...
